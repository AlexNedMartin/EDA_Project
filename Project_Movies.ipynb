# %% [markdown]
# <img src="https://images.unsplash.com/photo-1542204165-65bf26472b9b?q=80&w=3174&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" width="600" height="auto" />

# %% [markdown]
# # Programmatic Data Wrangling Project - TMDB

# %% [markdown]
# ### Introduction:
# This is small project where I will be undertaking Exploratory Data Analysis and drawing insights from a small, but comprehensive movie dataset.

# %% [markdown]
# ### Objectives:
# <ul>
#     <li>Data Cleaning</li>
#     <li>Data Wrangling</li>
#     <li>Exploratory Data Analysis (EDA)</li>
#     <li>Two movie comparison</li>
# </ul>

# %% [markdown]
# ### Importing libraries

# %%
# Import the required libraries
import numpy as np  # Maths
import seaborn as sns  # Visulaisations
import matplotlib.pyplot as plt  # Visualisations
import pandas as pd  # Data Analysis

# %% [markdown]
# ### Importing the dataset

# %%
import os  # Import the os module
current_dir = os.getcwd()  # Get the current working directory
print("Current working directory:", current_dir)  # Print the current working directory
# Out:
# Current working directory: /Users/alexmartin/Documents/GitHub/Digital-Futures/EDA Propject

# %%
# Load the dataset into a pandas dataframe
dataset="TMDB_movies.csv"
df=pd.read_csv(dataset)

# %% [markdown]
# Now some initiasl check to see if the data loaded correcty.

# %%
#Check the first 5 rows of the dataset
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#Check the last 5 rows of the dataset
df.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %% [markdown]
# Having checked the first five rows of the dataframe we can see that the data has been loaded correctly.

# %% [markdown]
# ### 3. Describing the dataset

# %%
#See how many rows and columns there are in the dataset
df.shape
# Out:
# (4803, 20)

# %%
#View the names of the columns
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
#check the datatypes
df.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
#Descriptive statistics including the non-numerical data types
df.describe(include='all')
# Out:
#               budget                         genres  \
# count   4.803000e+03                           4803
# unique           NaN                           1175
# top              NaN  [{"id": 18, "name": "Drama"}]
# freq             NaN                            370
# mean    2.904504e+07                            NaN
# std     4.072239e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     7.900000e+05                            NaN
# 50%     1.500000e+07                            NaN
# 75%     4.000000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage             id keywords  \
# count                                1712    4803.000000     4803
# unique                               1691            NaN     4222
# top     http://www.missionimpossible.com/            NaN       []
# freq                                    4            NaN      412
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# We will begin data cleaning by checking for null values.

# %%
#Check for null values in the dataset
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# From the list of null values we can see two columns that contain a large amount of null values.
# The 'homepage' column has 3091 null values and the 'tagline' columns contains 844 null values.
# We are going to drop those two colums from the dataframe as they don't contain any useful information for the purposes of this analysis.

# %%
#Drop the columns with the most null values
df.drop(columns=['homepage','tagline'], inplace=True)

# %%
#Check the remaining null values
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                3
# popularity              0
# production_companies    0
# production_countries    0
# release_date            1
# revenue                 0
# runtime                 2
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# We can see now that the two columns were dropped successfully. Now there are only a few remaining null values left to deal with.
# We want to remove the null values that exist in the 'runtime' and 'release date' columns. There are potentially only 6 rows to drop from the remianing 4803, so they will have negligible effect on our overall dataset.

# %%
# Drop rows with any null values
df.dropna(
    axis = 'rows', 
    how = 'any', # If any null values are present, drop that entire row
    subset = ['runtime', 'release_date', 'overview'],   # The columns we found to have null values
    inplace = True # Makes change permanent
)

# %%
#Check for remaing null values
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# There are no nulls remaning and we can proceed with our data wrangling

# %% [markdown]
# We also want to check for missing data. This is data that doesn't show as null but doesn't give us any useful information. The main check here is for values that are equal to zero when they shouldn't be.

# %%
# Check number of rows containing the value zero for each column
num_rows_with_zero = df.eq(0).sum() 

# Print the number of rows with 0 in each column
print("Number of rows with 0 in each column:")
print(num_rows_with_zero)
# Out:
# Number of rows with 0 in each column:
# budget                  1036
# genres                     0
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   0
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               0
# revenue                 1423
# runtime                   34
# spoken_languages           0
# status                     0
# title                      0
# vote_average              61
# vote_count                60
# dtype: int64

# %% [markdown]
# There are a lot of rows where with a value of 0. This missing data must be removed.

# %%
#New dataframe without the missing values.
new_df = df.loc[(df['budget'] != 0) #Excluding rows where budget = 0
                & (df['revenue'] != 0) #Excluding rows where revenue = 0
                & (df['vote_average'] != 0) #Excluding rows where vote_average = 0
                & (df['vote_count'] != 0)] #Excluding rows where vote_count = 0

# %%
# Check that the new dataframe contains no values equal to zero
num_rows_with_zero = new_df.eq(0).sum()  # Count the number of rows with 0 in each column

# Print the number of rows with 0 in each column
print("Number of rows with 0 in each column:")
print(num_rows_with_zero)
# Out:
# Number of rows with 0 in each column:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# Now there are no missing values and no null values in our dataset, we will do one last cleaning check for duplicates.

# %%
#Check if there are any duplicates in the DataFrame
has_duplicates = df.duplicated().any()

# Print if DataFrame has duplicates
print("\nDoes the DataFrame have duplicates?", has_duplicates)
# Out:
# Does the DataFrame have duplicates? False

# %% [markdown]
# There are no duplicated values in the dataframe so we can proceed with data wrangling.

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Some of the columns names are formatted incorrectly. They contain a list of dictionaries, that appear to be inputted as a string. These are genres, keywords, production_companies and production_compaines.

# %%
#Verifying the strange format
df.genres[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#Verifying the strange format
df.keywords[0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
#Verifying the strange format
df.production_companies[0]
# Out:
# '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]'

# %%
#Verifying the strange format
df.production_countries[0]
# Out:
# '[{"iso_3166_1": "US", "name": "United States of America"}, {"iso_3166_1": "GB", "name": "United Kingdom"}]'

# %%
## Function to extract genres for each datapoint
import ast ## This module can be used to evaluate literals, eg: transform string-lists back into lists
def extract_genres(x): 
    x = ast.literal_eval(x) ## Transform '['name', 'id']' back into ['name', 'id']
    Genres = [] ## Empty list to store the genres
    
    ''' Iterate through each dictionary '''
    for item in x: ## iterate for each dictionary in our list
        Genres.append(item['name']) ## Grab the 'name' key for each dictionary
        \
    ''' Return the Genres'''
    return Genres

## Apply the function to genres
df['extracted_genres'] = df['genres'].apply(extract_genres)

# %% [markdown]
# Source code: Alex Caian - Digital Futures

# %%
#Check function worked as intended
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
## Function to extract production countries for each datapoint
import ast ## This module can be used to evaluate literals, eg: transform string-lists back into lists
def extract_production_countries(x): 
    x = ast.literal_eval(x) ## Transform '['name', 'id']' back into ['name', 'id']
    production_countries = [] ## Empty list to store the genres
    
    ''' Iterate through each dictionary '''
    for item in x: ## iterate for each dictionary in our list
        production_countries.append(item['name']) ## Grab the 'name' key for each dictionary
        
    ''' Return the Genres'''
    return production_countries

## Apply the function to genres
df['extracted_counties'] = df['production_countries'].apply(extract_production_countries)

# %% [markdown]
# Source code: Alex Caian - Digital Futures

# %%
#Check function worked as intended
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
## Function to extract production companies for each datapoint
import ast ## This module can be used to evaluate literals, eg: transform string-lists back into lists
def extract_production_companies(x): 
    x = ast.literal_eval(x) ## Transform '['name', 'id']' back into ['name', 'id']
    production_companies = [] ## Empty list to store the genres
    
    ''' Iterate through each dictionary '''
    for item in x: ## iterate for each dictionary in our list
        production_companies.append(item['name']) ## Grab the 'name' key for each dictionary
        
    ''' Return the Genres'''
    return production_companies

## Apply the function to genres
df['extracted_companies'] = df['production_companies'].apply(extract_production_companies)

# %% [markdown]
# Source code: Alex Caian - Digital Futures

# %%
#Check function worked as intended
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %% [markdown]
# Now we have extracted the data for each data point and the dataset is clear of mssing values and null values. We can proceed with our exploratory data analysis.

# %% [markdown]
# <img src="https://images.unsplash.com/photo-1588600878108-578307a3cc9d?q=80&w=2952&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" width="600" height="auto" />

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Define your custom color palette
custom_palette = ["#2A2D34", "#009DDC", "#F26430"]

# Create the Seaborn color palette
sns.set_palette(custom_palette)

# Set the palette as the default for all plots
sns.set_palette(sns.color_palette(custom_palette))

# %% [markdown]
# #### Budget v. Revenue:

# %% [markdown]
# Here we will undertake some intial data exploration. We will start by looking at the budget of films and how that effects measurable KPIs such as revenue and popularity.

# %%
#Create a new dataframe to explore the effects of budget
#Dataframe contains only numeric values for purposes of correlation
budget_df = new_df[['title','budget','popularity','revenue','runtime','vote_average','vote_count']]\
    .sort_values('budget', ascending=False)\
    .set_index('title')\
    .copy()
budget_df.head()
# Out:
#                                                 budget  popularity  \
# title
# Pirates of the Caribbean: On Stranger Tides  380000000  135.413856
# Pirates of the Caribbean: At World's End     300000000  139.082615
# Avengers: Age of Ultron                      280000000  134.279229
# Superman Returns                             270000000   57.925623
# John Carter                                  260000000   43.926995
#
#                                                 revenue  runtime  \
# title
# Pirates of the Caribbean: On Stranger Tides  1045713802    136.0
# Pirates of the Caribbean: At World's End      961000000    169.0
# Avengers: Age of Ultron                      1405403694    141.0
# Superman Returns                              391081192    154.0
# John Carter                                   284139100    132.0
#
#                                              vote_average  vote_count
# title
# Pirates of the Caribbean: On Stranger Tides           6.4        4948
# ...

# %% [markdown]
# For our intial investigation we will explore how movie budgets effect revenue.

# %%
# Create a line plot to visualize the relationship between budget and revenue
plt.figure(figsize=(12, 6))  # Set the figure size
sns.lineplot(data=budget_df, x='budget', y='revenue', color='#009DDC')  # Plot the line plot
sns.regplot(data=budget_df, x='budget', y='revenue', scatter=False, color='#F26430', line_kws={"linestyle": "--"}, ci=None)  # Add a dashed trend line without confidence intervals
plt.title('Line Graph of Budget v. Revenue')  # Set the title of the plot
plt.xlabel('Budget ($M)')  # Set the x-axis label
plt.ylabel('Revenue ($M)')  # Set the y-axis label
plt.show()  # Display the plot

# %% [markdown]
# #### Key findings:
# <ul>
#     <li>There is a postive, linear relationship between budget and revenue.</li>
#     <li>This means that the higher the budget of a movie, the greater the revenue it will generate. This is what we expected to see.</li>
# <li>There is one movie that appears to be a outlier, where an abnormally high revenue was generated for its budget.</li>
# </ul>

# %% [markdown]
# ##### Outlier check:
#
# As a result of our inital finding, we will check what the name of the movie that had the highest revenue

# %%
# Return the index of the movie with the highest revenue
title_of_highest_revenue = budget_df['revenue'].idxmax()
print(title_of_highest_revenue)
# Out:
# Avatar

# %% [markdown]
# Now we will check the distribution, to see the extent to which 'Avatar' is an outlier.

# %%
# Create a boxplot to visualize the distribution of revenue
plt.figure(figsize=(12, 6))  # Set the figure size
sns.boxplot(data=budget_df['revenue'], orient='h', color='#009DDC')  # Plot the boxplot horizontally with the specified color
plt.title('Boxpot of Revenue Distribution')  # Add title to the plot
plt.xlabel('Revenue ($M)')  # Set the x-axis label
plt.show()  # Display the plot

# %% [markdown]
# #### Key findings:
# <ul>
#     <li>There is a negative skew to revenue.</li>
#     <li>This means that for the majority of movies do not generate vey high revenues, with only a small number of films able to be considered blockbusters.</li>
# <li>The movie 'Avatar' vastly exceeded the expected levels of revenue.</li>
# </ul>

# %% [markdown]
# #### Budget v. Popularity:
# We've seen from the graph above that higher budget movies are associated with higher revenues. I want to see if budget affects popularity of a movie. One would expect higher budgets mivies to be more popular as they have more resources to allocate towards marketing and hiring popular actors and directors.

# %%
# Creating a scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=budget_df, x='budget', y='popularity', color='#2A2D34')

# Fitting a linear regression line with dashed line and no confidence interval
sns.regplot(data=budget_df, x='budget', y='popularity', scatter=False, line_kws={'linestyle':'--'}, ci=None, color='#F26430')

# Adding title
plt.title('Scatter Plot of Popularity Score v. Budget')

plt.show()

# %% [markdown]
# #### Key findings:
# <ul>
#     <li>There is a very weak relationship between budget and popularity, although in general this shows movies with a higher budget tend to be more popular..</li>
#     <li>There are a few outliers here which go againest the trend and are more popular than one migh expect given theeir budgets.
#         .</li>
# </ul>

# %%
# Get the top 6 most popular movies along with their popularity scores
top_6_popular_movies = budget_df.nlargest(6, 'popularity')[['popularity']]
print(top_6_popular_movies)
# Out:
#                          popularity
# title
# Minions                  875.581305
# Interstellar             724.247784
# Deadpool                 514.569956
# Guardians of the Galaxy  481.098624
# Mad Max: Fury Road       434.278564
# Jurassic World           418.708552

# %% [markdown]
# These are the top 6 most popuar movies which outperform their expected popularity, based on revenue the most. These are all movies one might consider to be blockbusters.

# %% [markdown]
# #### Correlation Matrix:

# %% [markdown]
# To visualise all the numeric variables that could have a relationship with budget, we will consider a correlation matrix. This will show the relationship between all the numeric variable we have available to us.

# %%
# Correlation heatmaps
# Using seaborn to create a heatmap of the correlation matrix of the budget_df dataframe
sns.heatmap(budget_df.corr(),  # Compute the correlation matrix and create a heatmap
           annot=True,  # Display the correlation values on the heatmap
           mask = np.triu(budget_df.corr()),  # Mask the upper triangle of the heatmap
           cmap = custom_palette,# Set the color map to the custom_palette
            vmin=-1, 
            vmax=1 
           )
plt.show()  # Display the heatmap

# %%
#Correlation table to accompany the correlation matrix
budget_df.corr()
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.431744  0.705306  0.229712     -0.035757
# popularity    0.431744    1.000000  0.602122  0.182388      0.288189
# revenue       0.705306    0.602122  1.000000  0.233236      0.188014
# runtime       0.229712    0.182388  0.233236  1.000000      0.386199
# vote_average -0.035757    0.288189  0.188014  0.386199      1.000000
# vote_count    0.539997    0.749005  0.756143  0.258101      0.380825
#
#               vote_count
# budget          0.539997
# popularity      0.749005
# revenue         0.756143
# runtime         0.258101
# vote_average    0.380825
# vote_count      1.000000

# %% [markdown]
# #### Key findings:
# <ul>
#     <li>Budget is most strongly correlated with revenue. We saw this pattern in our first visualisation (7.1).This makes sense, as the higher the budget, the more money production companies have to spend on marketing, production, salaries etc, which all help to drive revenue.</li>
#     <li>There is a medium sized correlation between budget and vote_count. this suggests that higher budget movies reach larger audiences who can then vote on the movie.</li>
#      <li>Budget has a very small negative correlation with vote_average. This suggests that having a large budget doesn't translate into movie quality.</li>
#     <li>Main takeaway: Having a larger budget will generally result in a more poluar moving being produced which generates higher revenues. However it does not effect the movies quality as seen by the lack of imact on vote_average.</li>
#
# </ul>

# %% [markdown]
# <img src="https://images.unsplash.com/photo-1485095329183-d0797cdc5676?q=80&w=2940&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" width="600" height="auto" />

# %% [markdown]
# ### 8. Two Movies Comparison
# #### Avatar v. Titanic

# %% [markdown]
# Haivng explored the effect of budget on revenue and popularity, we will now look closer at the two films which have the highest revenues. This is so we can see what similarities/differences they have and we will see if we can draw any conclusions as to why they are so successful.

# %%
# Creating a new dataframe containing only the two films we are looking at.
highest_budgets = new_df.sort_values('revenue',  
                                     ascending=False)\
                                    .head(2)\
                                    .copy()  

highest_budgets
# Out:
#        budget                                             genres     id  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...    597
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
#
#    original_title                                           overview  \
# 0          Avatar  In the 22nd century, a paraplegic Marine is di...
# 25        Titanic  84 years later, a 101-year-old woman named Ros...
#
#     popularity                               production_companies  \
# 0   150.437577  [{"name": "Ingenious Film Partners", "id": 289...
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...
#
#                                  production_countries release_date  \
# ...

# %% [markdown]
# For the purposes of evaluation, we want to add a new column to the dataframe representing value for money.
#
# We will use value for money to see which of the two films returned the most reveune per amount of budget spent. This will show which one of the movies were most efficent with their spending and got the best return for its investors.
#
# We calculate value for money as follows:
#
#             value for money = (revenue / budget) x 100

# %%
# Create a new column 'value_for_money'
highest_budgets['value_for_money'] = (highest_budgets['revenue'] / highest_budgets['budget']) * 100

#Using indexing to check the column has been created successfully.
highest_budgets.iloc[:, [5, -1]]
# Out:
#    original_title  value_for_money
# 0          Avatar      1176.356577
# 25        Titanic       922.517094

# %%
dataset = highest_budgets

# Create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))  # 2 rows, 2 columns

# Plot different aspects of the dataset on separate subplots

#Bar chart comparing the popularity score for both movies
sns.barplot(data=dataset, x='title', y='popularity', ax=axs[0, 0], palette=custom_palette)
axs[0, 0].set_title('Popularity')
axs[0, 0].set_xlabel('Title')
axs[0, 0].set_ylabel('Popularity')

#Bar chart showing revenue of both movies
sns.barplot(data=dataset, x='title', y='revenue', ax=axs[0, 1], palette=custom_palette)
axs[0, 1].set_title('Revenue')
axs[0, 1].set_xlabel('Title')
axs[0, 1].set_ylabel('Revenue')

#Bar chart showing vote_average of both movies
sns.barplot(data=dataset, x='title', y='budget', ax=axs[1, 0], palette=custom_palette)
axs[1, 0].set_title('Budget')
axs[1, 0].set_xlabel('Title')
axs[1, 0].set_ylabel('Budget')

#Bar chart showing value for money
sns.barplot(data=dataset, x='title', y='value_for_money', ax=axs[1, 1], palette=custom_palette)
axs[1, 1].set_title('Value for Money')
axs[1, 1].set_xlabel('Title')
axs[1, 1].set_ylabel('Value for Money')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/md/rprl_jf94cx0vvvnxffb9cn00000gn/T/ipykernel_1253/2951722211.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=dataset, x='title', y='popularity', ax=axs[0, 0], palette=custom_palette)
# /var/folders/md/rprl_jf94cx0vvvnxffb9cn00000gn/T/ipykernel_1253/2951722211.py:9: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(data=dataset, x='title', y='popularity', ax=axs[0, 0], palette=custom_palette)
# /var/folders/md/rprl_jf94cx0vvvnxffb9cn00000gn/T/ipykernel_1253/2951722211.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=dataset, x='title', y='revenue', ax=axs[0, 1], palette=custom_palette)
# ...

# %% [markdown]
# #### Key findings:
# <ul>
#     <li>Avatar is more popualr than Titanic.</li>
#     <li>Avatar genrated higher revenues than Titanic.</li>
#      <li>Avatar had a higher budget than Titanic.</li>
#     <li>Avatar represents greater value for money than Titanic.</li>
#     <li>From this we can conclude that Avatar is the more succesful movie across all measureable metrics availbale to us.</li>
#     <li>Despite both appearing as outliers in the overall dataset, these two blockbusters still show the same patterns as the rest of the dataset; hihgher budgets result in higher populartiy and higher revneue.</li>
#
# </ul>
